# %% [markdown]
# Statistical estimation with a 95% confidence interval for number and percentage of inpatient beds occupied by COVID-19 patients for the given state and date
#
# Data Dictionary:
# 1. state (string): The two digit state code
# 2. collection_date (date): Date estimated
# 3. Inpatient Beds Occupied by COVID-19 Patients Estimated (double): Estimated number of inpatient beds occupied by COVID-19 patients for the given state and date
# 4. Count LL (double): Estimated number of inpatient beds occupied by COVID-19 patients for the given state and date, lower limit, 95% confidence interval
# 5. Count UL (double): Estimated number of inpatient beds occupied by COVID-19 patients for the given state and date, upper limit, 95% confidence interval
# 6. Percentage of Inpatient Beds Occupied by COVID-19 Patients Estimated (double): Estimated percentage of inpatient beds occupied by COVID-19 patients for the given state and date
# 7. Percentage LL (double): Estimated percentage of inpatient beds occupied by COVID-19 patients for the given state and date, lower limit, 95% confidence interval
# 8. Percentage UL (double): Estimated percentage of inpatient beds occupied by COVID-19 patients for the given state and date, upper limit, 95% confidence interval

# %%
import pandas as pd

# %%
# Loading csv
csv = "Resources/estimated_inpatient_original.csv"
csv_df = pd.read_csv(csv)
csv_df
# Out:
#      state collection_date  \
# 0       CW      2020-08-18
# 1       CW      2020-08-19
# 2       CW      2020-08-20
# 3       CW      2020-08-21
# 4       CW      2020-08-22
# ...    ...             ...
# 1691    WY      2020-09-16
# 1692    WV      2020-09-17
# 1693    WY      2020-09-17
# 1694    WV      2020-09-18
# 1695    WY      2020-09-18
#
#      Inpatient Beds Occupied by COVID-19 Patients Estimated Count LL Count UL  \
# 0                                                53,956       53,534   54,378
# 1                                                52,881       52,484   53,278
# 2                                                51,490       51,143   51,838
# 3                                                50,243       49,877   50,608
# 4                                                48,322       48,039   48,606
# ...                                                 ...          ...      ...
# 1691                                                 29           26       32
# 1692                                                234          232      236
# 1693                                                 33           33       33
# 1694                                                232          232      232
# 1695                                                 33           30       36
#
#       Percentage of Inpatient Beds Occupied by COVID-19 Patients Estimated  \
# 0                                                  7.34
# 1                                                  7.17
# 2                                                  6.94
# 3                                                  6.77
# 4                                                  6.53
# ...                                                 ...
# 1691                                               1.92
# 1692                                               4.11
# 1693                                               2.19
# 1694                                               4.14
# 1695                                               2.18
#
#       Percentage LL  Percentage UL Total Inpatient Beds Total LL Total UL
# 0              6.89           7.79              701,765  698,684  704,846
# 1              6.75           7.59              703,351  700,411  706,291
# 2              6.57           7.31              707,737  704,976  710,498
# 3              6.34           7.20              708,898  705,285  712,512
# 4              6.20           6.85              706,285  703,160  709,410
# ...             ...            ...                  ...      ...      ...
# 1691          -1.61           5.46                1,510    1,387    1,633
# 1692           4.11           4.11                5,698    5,698    5,698
# 1693           2.19           2.19                1,510    1,510    1,510
# 1694           4.14           4.14                5,609    5,609    5,609
# 1695          -1.32           5.69                1,511    1,388    1,634
#
# [1696 rows x 11 columns]

# %%
# dropped all rows with NaN values 
clean_df = csv_df.dropna(how='any')
clean_df
# Out:
#      state collection_date  \
# 0       CW      2020-08-18
# 1       CW      2020-08-19
# 2       CW      2020-08-20
# 3       CW      2020-08-21
# 4       CW      2020-08-22
# ...    ...             ...
# 1691    WY      2020-09-16
# 1692    WV      2020-09-17
# 1693    WY      2020-09-17
# 1694    WV      2020-09-18
# 1695    WY      2020-09-18
#
#      Inpatient Beds Occupied by COVID-19 Patients Estimated Count LL Count UL  \
# 0                                                53,956       53,534   54,378
# 1                                                52,881       52,484   53,278
# 2                                                51,490       51,143   51,838
# 3                                                50,243       49,877   50,608
# 4                                                48,322       48,039   48,606
# ...                                                 ...          ...      ...
# 1691                                                 29           26       32
# 1692                                                234          232      236
# 1693                                                 33           33       33
# 1694                                                232          232      232
# 1695                                                 33           30       36
#
#       Percentage of Inpatient Beds Occupied by COVID-19 Patients Estimated  \
# 0                                                  7.34
# 1                                                  7.17
# 2                                                  6.94
# 3                                                  6.77
# 4                                                  6.53
# ...                                                 ...
# 1691                                               1.92
# 1692                                               4.11
# 1693                                               2.19
# 1694                                               4.14
# 1695                                               2.18
#
#       Percentage LL  Percentage UL Total Inpatient Beds Total LL Total UL
# 0              6.89           7.79              701,765  698,684  704,846
# 1              6.75           7.59              703,351  700,411  706,291
# 2              6.57           7.31              707,737  704,976  710,498
# 3              6.34           7.20              708,898  705,285  712,512
# 4              6.20           6.85              706,285  703,160  709,410
# ...             ...            ...                  ...      ...      ...
# 1691          -1.61           5.46                1,510    1,387    1,633
# 1692           4.11           4.11                5,698    5,698    5,698
# 1693           2.19           2.19                1,510    1,510    1,510
# 1694           4.14           4.14                5,609    5,609    5,609
# 1695          -1.32           5.69                1,511    1,388    1,634
#
# [1696 rows x 11 columns]

# %%
# checking names of states 
clean_df["state"].unique()
# Out:
# array(['CW', 'AL', 'DC', 'AR', 'CA', 'CT', 'GA', 'ID', 'IN', 'KS', 'LA',
#        'MD', 'MI', 'AK', 'FL', 'DE', 'IA', 'MA', 'AZ', 'CO', 'HI', 'IL',
#        'KY', 'ME', 'MN', 'MS', 'MT', 'NV', 'ND', 'NJ', 'NY', 'PR', 'RI',
#        'VT', 'MO', 'NE', 'NH', 'OR', 'SD', 'TX', 'NC', 'NM', 'OH', 'OK',
#        'PA', 'SC', 'TN', 'UT', 'VA', 'WA', 'WI', 'WV', 'WY'], dtype=object)

# %%
# checking number of states 
clean_df["state"].nunique()
# Out:
# 53

# %%
# Dropping the state columns with the alue 'CW'
clean_states = csv_df.drop(csv_df.loc[csv_df['state']== 'CW'].index)
clean_states
# Out:
#      state collection_date  \
# 32      AL      2020-08-18
# 33      DC      2020-08-18
# 34      AL      2020-08-19
# 35      DC      2020-08-19
# 36      AL      2020-08-20
# ...    ...             ...
# 1691    WY      2020-09-16
# 1692    WV      2020-09-17
# 1693    WY      2020-09-17
# 1694    WV      2020-09-18
# 1695    WY      2020-09-18
#
#      Inpatient Beds Occupied by COVID-19 Patients Estimated Count LL Count UL  \
# 32                                                1,516        1,516    1,516
# 33                                                  143          136      150
# 34                                                1,442        1,427    1,456
# 35                                                  130          130      130
# 36                                                1,379        1,373    1,386
# ...                                                 ...          ...      ...
# 1691                                                 29           26       32
# 1692                                                234          232      236
# 1693                                                 33           33       33
# 1694                                                232          232      232
# 1695                                                 33           30       36
#
#       Percentage of Inpatient Beds Occupied by COVID-19 Patients Estimated  \
# 32                                                10.74
# 33                                                 5.31
# 34                                                10.24
# 35                                                 4.81
# 36                                                 9.77
# ...                                                 ...
# 1691                                               1.92
# 1692                                               4.11
# 1693                                               2.19
# 1694                                               4.14
# 1695                                               2.18
#
#       Percentage LL  Percentage UL Total Inpatient Beds Total LL Total UL
# 32            10.49          10.99               14,135   14,080   14,190
# 33             0.96           9.67                2,691    2,477    2,905
# 34             9.45          11.04               14,094   13,993   14,195
# 35             4.81           4.81                2,701    2,701    2,701
# 36             9.46          10.08               14,127   14,101   14,153
# ...             ...            ...                  ...      ...      ...
# 1691          -1.61           5.46                1,510    1,387    1,633
# 1692           4.11           4.11                5,698    5,698    5,698
# 1693           2.19           2.19                1,510    1,510    1,510
# 1694           4.14           4.14                5,609    5,609    5,609
# 1695          -1.32           5.69                1,511    1,388    1,634
#
# [1664 rows x 11 columns]

# %%
# Dropping the state columns with the alue 'PR' 
df = clean_states.drop(clean_states.loc[clean_states['state']== 'PR'].index)
df
# Out:
#      state collection_date  \
# 32      AL      2020-08-18
# 33      DC      2020-08-18
# 34      AL      2020-08-19
# 35      DC      2020-08-19
# 36      AL      2020-08-20
# ...    ...             ...
# 1691    WY      2020-09-16
# 1692    WV      2020-09-17
# 1693    WY      2020-09-17
# 1694    WV      2020-09-18
# 1695    WY      2020-09-18
#
#      Inpatient Beds Occupied by COVID-19 Patients Estimated Count LL Count UL  \
# 32                                                1,516        1,516    1,516
# 33                                                  143          136      150
# 34                                                1,442        1,427    1,456
# 35                                                  130          130      130
# 36                                                1,379        1,373    1,386
# ...                                                 ...          ...      ...
# 1691                                                 29           26       32
# 1692                                                234          232      236
# 1693                                                 33           33       33
# 1694                                                232          232      232
# 1695                                                 33           30       36
#
#       Percentage of Inpatient Beds Occupied by COVID-19 Patients Estimated  \
# 32                                                10.74
# 33                                                 5.31
# 34                                                10.24
# 35                                                 4.81
# 36                                                 9.77
# ...                                                 ...
# 1691                                               1.92
# 1692                                               4.11
# 1693                                               2.19
# 1694                                               4.14
# 1695                                               2.18
#
#       Percentage LL  Percentage UL Total Inpatient Beds Total LL Total UL
# 32            10.49          10.99               14,135   14,080   14,190
# 33             0.96           9.67                2,691    2,477    2,905
# 34             9.45          11.04               14,094   13,993   14,195
# 35             4.81           4.81                2,701    2,701    2,701
# 36             9.46          10.08               14,127   14,101   14,153
# ...             ...            ...                  ...      ...      ...
# 1691          -1.61           5.46                1,510    1,387    1,633
# 1692           4.11           4.11                5,698    5,698    5,698
# 1693           2.19           2.19                1,510    1,510    1,510
# 1694           4.14           4.14                5,609    5,609    5,609
# 1695          -1.32           5.69                1,511    1,388    1,634
#
# [1632 rows x 11 columns]

# %%
# Checking how many states are in the df after the deletions 
df["state"].nunique()
# Out:
# 51

# %%
# Sorting data by state
sorted_df = df.sort_values(by=['state'])
sorted_df
# Out:
#      state collection_date  \
# 432     AK      2020-09-03
# 435     AK      2020-09-06
# 434     AK      2020-09-05
# 433     AK      2020-09-04
# 425     AK      2020-08-27
# ...    ...             ...
# 1671    WY      2020-09-06
# 1641    WY      2020-08-22
# 1673    WY      2020-09-07
# 1645    WY      2020-08-24
# 1695    WY      2020-09-18
#
#      Inpatient Beds Occupied by COVID-19 Patients Estimated Count LL Count UL  \
# 432                                                  47           47       47
# 435                                                  41           41       41
# 434                                                  44           44       44
# 433                                                  46           46       46
# 425                                                  36           36       36
# ...                                                 ...          ...      ...
# 1671                                                 32           32       32
# 1641                                                 24           23       25
# 1673                                                 32           32       32
# 1645                                                 35           34       36
# 1695                                                 33           30       36
#
#       Percentage of Inpatient Beds Occupied by COVID-19 Patients Estimated  \
# 432                                                3.31
# 435                                                2.75
# 434                                                2.83
# 433                                                3.31
# 425                                                1.64
# ...                                                 ...
# 1671                                               2.12
# 1641                                               1.74
# 1673                                               2.12
# 1645                                               2.41
# 1695                                               2.18
#
#       Percentage LL  Percentage UL Total Inpatient Beds Total LL Total UL
# 432            3.10           3.51                1,210    1,203    1,217
# 435            2.02           3.48                1,201    1,176    1,226
# 434            2.83           2.83                1,200    1,177    1,223
# 433            2.62           3.99                1,210    1,187    1,233
# 425            1.64           1.64                1,277    1,277    1,277
# ...             ...            ...                  ...      ...      ...
# 1671           0.69           3.55                1,511    1,437    1,585
# 1641           0.35           3.14                1,378    1,309    1,447
# 1673           0.87           3.37                1,511    1,446    1,576
# 1645           2.41           2.41                1,454    1,407    1,501
# 1695          -1.32           5.69                1,511    1,388    1,634
#
# [1632 rows x 11 columns]

# %%
# Setting collection date value to datetime
sorted_df.collection_date = pd.to_datetime(sorted_df.collection_date)

# %%
# Writing df to csv 
sorted_df.to_csv('indexed_cleaned_estimated_beds.csv', index=False)

# %%
# Number of dates recorded
sorted_df["collection_date"].unique()
# Out:
# array(['2020-09-03T00:00:00.000000000', '2020-09-06T00:00:00.000000000',
#        '2020-09-05T00:00:00.000000000', '2020-09-04T00:00:00.000000000',
#        '2020-08-27T00:00:00.000000000', '2020-09-02T00:00:00.000000000',
#        '2020-09-01T00:00:00.000000000', '2020-08-31T00:00:00.000000000',
#        '2020-08-30T00:00:00.000000000', '2020-09-18T00:00:00.000000000',
#        '2020-08-18T00:00:00.000000000', '2020-08-19T00:00:00.000000000',
#        '2020-08-20T00:00:00.000000000', '2020-08-21T00:00:00.000000000',
#        '2020-08-22T00:00:00.000000000', '2020-08-23T00:00:00.000000000',
#        '2020-08-24T00:00:00.000000000', '2020-08-29T00:00:00.000000000',
#        '2020-08-25T00:00:00.000000000', '2020-08-26T00:00:00.000000000',
#        '2020-09-07T00:00:00.000000000', '2020-09-08T00:00:00.000000000',
#        '2020-08-28T00:00:00.000000000', '2020-09-09T00:00:00.000000000',
#        '2020-09-12T00:00:00.000000000', '2020-09-14T00:00:00.000000000',
#        '2020-09-15T00:00:00.000000000', '2020-09-11T00:00:00.000000000',
#        '2020-09-10T00:00:00.000000000', '2020-09-16T00:00:00.000000000',
#        '2020-09-13T00:00:00.000000000', '2020-09-17T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
# Number of dates per state
sorted_df[["collection_date", "state"]].nunique()
# Out:
# collection_date    32
# state              51
# dtype: int64
